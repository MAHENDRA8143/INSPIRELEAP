# %% [markdown]
# # Diabetes Prediction Workflow
# This notebook is a starter for exploring dataset quality and feature behavior.

# %%
import pandas as pd
from src.data_loader import load_diabetes_dataset

df = load_diabetes_dataset()
df.head()
